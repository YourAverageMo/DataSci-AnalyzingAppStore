# %% [markdown]
# # Introduction
#
# In this notebook, we will do a comprehensive analysis of the Android app market by comparing thousands of apps in the Google Play store.

# %% [markdown]
# # About the Dataset of Google Play Store Apps & Reviews

# %% [markdown]
# **Data Source:** <br>
# App and review data was scraped from the Google Play Store by Lavanya Gupta in 2018. Original files listed [here](
# https://www.kaggle.com/lava18/google-play-store-apps).

# %% [markdown]
# # Import Statements

# %%
import pandas as pd
import plotly.express as px

# %% [markdown]
# # Notebook Presentation

# %%
# Show numeric output in decimal format e.g., 2.15
pd.options.display.float_format = '{:,.2f}'.format

# %% [markdown]
# # Read the Dataset

# %%
df_apps = pd.read_csv('apps.csv')

# %% [markdown]
# # Data Cleaning

# %% [markdown]
# **Challenge**: How many rows and columns does `df_apps` have? What are the column names? Look at a random sample of 5 different rows with [.sample()](https://pandas.pydata.org/pandas-docs/stable/reference/api/pandas.DataFrame.sample.html).

# %%
df_apps.sample(5)
# Out:
#                                                      App         Category  \
# 10644                           Dream League Soccer 2018             GAME
# 523         Pacify (Android P theme) - Theme for Xperia™  PERSONALIZATION
# 4374                      C4droid - C/C++ compiler & IDE           FAMILY
# 14                     I'm Rich/Eu sou Rico/أنا غني/我很有錢        LIFESTYLE
# 5165   Comic Es - Shojo manga / love comics free of c...           COMICS
#
#        Rating  Reviews  Size_MBs     Installs  Type    Price Content_Rating  \
# 10644    4.60  9882639     74.00  100,000,000  Free        0       Everyone
# 523       NaN        1      1.80           10  Paid    $0.99       Everyone
# 4374     4.70     2890     19.00       50,000  Paid    $2.99       Everyone
# 14        NaN        0     40.00            0  Paid  $399.99       Everyone
# 5165     3.90     2181     10.00      100,000  Free        0           Teen
#
#                 Genres      Last_Updated         Android_Ver
# ...

# %% [markdown]
# ### Drop Unused Columns
#
# **Challenge**: Remove the columns called `Last_Updated` and `Android_Version` from the DataFrame. We will not use these columns.

# %%
df_apps.drop(["Last_Updated","Android_Ver"], axis=1, inplace=True)

# %%
df_apps.sample(5)
# Out:
#                   App             Category  Rating  Reviews  Size_MBs  \
# 6868   Canvas Student            EDUCATION    4.50    42828      6.95
# 5326   EGW Writings 2  BOOKS_AND_REFERENCE    4.70     6547     16.00
# 980     CK Pharmacies   HEALTH_AND_FITNESS    2.70        3      9.40
# 600     DK TEL Dialer        COMMUNICATION     NaN        0      4.20
# 6533  Ninesky Browser        COMMUNICATION    4.20    42925      2.80
#
#        Installs  Type Price Content_Rating             Genres
# 6868  1,000,000  Free     0       Everyone          Education
# 5326    100,000  Free     0       Everyone  Books & Reference
# 980         100  Free     0   Everyone 10+   Health & Fitness
# 600          50  Free     0       Everyone      Communication
# 6533  1,000,000  Free     0       Everyone      Communication

# %% [markdown]
# ### Find and Remove NaN values in Ratings
#
# **Challenge**: How may rows have a NaN value (not-a-number) in the Ratings column? Create DataFrame called `df_apps_clean` that does not include these rows.

# %%
df_apps.isna().sum()
# Out:
# App                  0
# Category             0
# Rating            1474
# Reviews              0
# Size_MBs             0
# Installs             0
# Type                 1
# Price                0
# Content_Rating       0
# Genres               0
# dtype: int64

# %%
nan_rows = df_apps[df_apps.Rating.isna()]
df_apps_clean = df_apps.dropna()
df_apps_clean.shape
# Out:
# (9367, 10)

# %% [markdown]
# ### Find and Remove Duplicates
#
# **Challenge**: Are there any duplicates in data? Check for duplicates using the [.duplicated()](https://pandas.pydata.org/pandas-docs/stable/reference/api/pandas.DataFrame.duplicated.html) function. How many entries can you find for the "Instagram" app? Use [.drop_duplicates()](https://pandas.pydata.org/pandas-docs/stable/reference/api/pandas.DataFrame.drop_duplicates.html) to remove any duplicates from `df_apps_clean`.

# %%
df_apps_clean.duplicated().sum()
# Out:
# 476

# %%
df_apps_clean = df_apps_clean.drop_duplicates(subset=["App","Type","Price"])

# %% [markdown]
# # Find Highest Rated Apps
#
# **Challenge**: Identify which apps are the highest rated. What problem might you encounter if you rely exclusively on ratings alone to determine the quality of an app?

# %%
df_apps_clean.sort_values("Rating",ascending=False)
# Out:
#                                           App      Category  Rating  Reviews  \
# 21                        KBA-EZ Health Guide       MEDICAL    5.00        4
# 1230                             Sway Medical       MEDICAL    5.00        3
# 1227                        AJ Men's Grooming     LIFESTYLE    5.00        2
# 1224                           FK Dedinje BGD        SPORTS    5.00       36
# 1223                          CB VIDEO VISION   PHOTOGRAPHY    5.00       13
# ...                                       ...           ...     ...      ...
# 1314                              CR Magazine      BUSINESS    1.00        1
# 1932           FE Mechanical Engineering Prep        FAMILY    1.00        2
# 357                         Speech Therapy: F        FAMILY    1.00        1
# 818   Familial Hypercholesterolaemia Handbook       MEDICAL    1.00        2
# 1208                           Thistletown CI  PRODUCTIVITY    1.00        1
#
# ...

# %% [markdown]
# # Find 5 Largest Apps in terms of Size (MBs)
#
# **Challenge**: What's the size in megabytes (MB) of the largest Android apps in the Google Play Store. Based on the data, do you think there could be limit in place or can developers make apps as large as they please?

# %%
df_apps_clean.sort_values("Size_MBs",ascending=False).head()
# Out:
#                                   App            Category  Rating  Reviews  \
# 9942   Talking Babsy Baby: Baby Games           LIFESTYLE    4.00   140995
# 10687          Hungry Shark Evolution                GAME    4.50  6074334
# 9943            Miami crime simulator                GAME    4.00   254518
# 9944     Gangster Town: Vice District              FAMILY    4.30    65146
# 3144                       Vi Trainer  HEALTH_AND_FITNESS    3.60      124
#
#        Size_MBs     Installs  Type Price Content_Rating  \
# 9942     100.00   10,000,000  Free     0       Everyone
# 10687    100.00  100,000,000  Free     0           Teen
# 9943     100.00   10,000,000  Free     0     Mature 17+
# 9944     100.00   10,000,000  Free     0     Mature 17+
# 3144     100.00        5,000  Free     0       Everyone
#
#                        Genres
# 9942   Lifestyle;Pretend Play
# 10687                  Arcade
# 9943                   Action
# 9944               Simulation
# ...

# %% [markdown]
# # Find the 5 App with Most Reviews
#
# **Challenge**: Which apps have the highest number of reviews? Are there any paid apps among the top 50?

# %%
df_apps_clean.sort_values("Reviews",ascending=False).head()
# Out:
#                                             App       Category  Rating  \
# 10805                                  Facebook         SOCIAL    4.10
# 10785                        WhatsApp Messenger  COMMUNICATION    4.40
# 10806                                 Instagram         SOCIAL    4.50
# 10784  Messenger – Text and Video Chat for Free  COMMUNICATION    4.00
# 10650                            Clash of Clans           GAME    4.60
#
#         Reviews  Size_MBs       Installs  Type Price Content_Rating  \
# 10805  78158306      5.30  1,000,000,000  Free     0           Teen
# 10785  69119316      3.50  1,000,000,000  Free     0       Everyone
# 10806  66577313      5.30  1,000,000,000  Free     0           Teen
# 10784  56642847      3.50  1,000,000,000  Free     0       Everyone
# 10650  44891723     98.00    100,000,000  Free     0   Everyone 10+
#
#               Genres
# 10805         Social
# 10785  Communication
# 10806         Social
# 10784  Communication
# ...

# %% [markdown]
# # Plotly Pie and Donut Charts - Visualise Categorical Data: Content Ratings

# %%
ratings = df_apps_clean.Content_Rating.value_counts().to_frame()
ratings
# Out:
#                  Content_Rating
# Everyone                   6621
# Teen                        912
# Mature 17+                  357
# Everyone 10+                305
# Adults only 18+               3
# Unrated                       1

# %%
# so the teacher was doing it this⬇ way but that doesnt show the labels because you are refering to a pandas series object. so im not using it

# or it turns out u could just convert the ratings series .to_frame() like i did above. that gives you the same result but its extra steps...

# fig = px.pie(labels=ratings, values=ratings.values,title="Content Rating",hole=0.6)
# fig.update_traces(textposition="outside", textinfo="percent+label")

# fig.show()

# this⬇ is the proper way to do it just use that actual df...
fig = px.pie(data_frame=df_apps_clean, names=df_apps_clean.Content_Rating, title='Content Rating', hole=0.6)

fig.update_traces(textposition="outside", textinfo="percent+label")

fig.show()
# Out:
# <div>                            <div id="8160ec31-6394-4dd1-90cf-a62765401949" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("8160ec31-6394-4dd1-90cf-a62765401949")) {                    Plotly.newPlot(                        "8160ec31-6394-4dd1-90cf-a62765401949",                        [{"domain":{"x":[0.0,1.0],"y":[0.0,1.0]},"hole":0.6,"hovertemplate":"Content_Rating=%{label}<extra></extra>","labels":["Everyone","Everyone","Everyone","Everyone","Everyone","Everyone","Everyone","Everyone","Everyone","Everyone","Everyone","Everyone","Everyone","Everyone","Everyone","Teen","Everyone","Everyone","Everyone","Everyone","Everyone","Mature 17+","Everyone","Everyone 10+","Everyone","Teen","Teen","Everyone","Everyone","Everyone","Mature 17+","Everyone","
# ...

# %% [markdown]
# # Numeric Type Conversion: Examine the Number of Installs
#
# **Challenge**: How many apps had over 1 billion (that's right - BILLION) installations? How many apps just had a single install?
#
# Check the datatype of the Installs column.
#
# Count the number of apps at each level of installations.
#
# Convert the number of installations (the Installs column) to a numeric data type. Hint: this is a 2-step process. You'll have make sure you remove non-numeric characters first.

# %%
df_apps_clean.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 8199 entries, 21 to 10835
# Data columns (total 10 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   App             8199 non-null   object
#  1   Category        8199 non-null   object
#  2   Rating          8199 non-null   float64
#  3   Reviews         8199 non-null   int64
#  4   Size_MBs        8199 non-null   float64
#  5   Installs        8199 non-null   int64
#  6   Type            8199 non-null   object
#  7   Price           8199 non-null   float64
#  8   Content_Rating  8199 non-null   object
#  9   Genres          8199 non-null   object
# dtypes: float64(3), int64(2), object(5)
# memory usage: 704.6+ KB

# %%
df_apps_clean[["App","Installs"]].groupby("Installs").count()
# Out:
#                 App
# Installs
# 1                 3
# 1,000           698
# 1,000,000      1417
# 1,000,000,000    20
# 10               69
# 10,000          988
# 10,000,000      933
# 100             303
# 100,000        1096
# 100,000,000     189
# 5                 9
# 5,000           425
# 5,000,000       607
# 50               56
# 50,000          457
# 50,000,000      202
# 500             199
# 500,000         504
# 500,000,000      24

# %%
df_apps_clean.Installs = df_apps_clean.Installs.str.replace(",", "")
df_apps_clean.Installs = pd.to_numeric(df_apps_clean.Installs)
df_apps_clean[["App","Installs"]].groupby("Installs").count()
# Out:
#              App
# Installs
# 1              3
# 5              9
# 10            69
# 50            56
# 100          303
# 500          199
# 1000         698
# 5000         425
# 10000        988
# 50000        457
# 100000      1096
# 500000       504
# 1000000     1417
# 5000000      607
# 10000000     933
# 50000000     202
# 100000000    189
# 500000000     24
# 1000000000    20

# %% [markdown]
# # Find the Most Expensive Apps, Filter out the Junk, and Calculate a (ballpark) Sales Revenue Estimate
#
# Let's examine the Price column more closely.
#
# **Challenge**: Convert the price column to numeric data. Then investigate the top 20 most expensive apps in the dataset.
#
# Remove all apps that cost more than $250 from the `df_apps_clean` DataFrame.
#
# Add a column called 'Revenue_Estimate' to the DataFrame. This column should hold the price of the app times the number of installs. What are the top 10 highest grossing paid apps according to this estimate? Out of the top 10 highest grossing paid apps, how many are games?

# %%
df_apps_clean.Price = pd.to_numeric(df_apps_clean.Price.str.replace("$", ""))
df_apps_clean.Price

# %% [markdown]
# ### The most expensive apps sub $250

# %%
df_apps_clean.Price[df_apps_clean.Price <250].max()
# Out:
# 79.99

# %% [markdown]
# ### Highest Grossing Paid Apps (ballpark estimate)

# %%
df_apps_clean["Revenue_Estimate"]= df_apps_clean.Installs.mul(df_apps_clean.Price)
df_apps_clean.sort_values("Revenue_Estimate", ascending=False).head()
# Out:
#                                 App   Category  Rating  Reviews  Size_MBs  \
# 9220                      Minecraft     FAMILY    4.50  2376564     19.00
# 5765                      I am rich  LIFESTYLE    3.80     3547      1.80
# 4606              I Am Rich Premium    FINANCE    4.10     1867      4.70
# 8825                  Hitman Sniper       GAME    4.60   408292     29.00
# 7151  Grand Theft Auto: San Andreas       GAME    4.40   348962     26.00
#
#       Installs  Type  Price Content_Rating                     Genres  \
# 9220  10000000  Paid   6.99   Everyone 10+  Arcade;Action & Adventure
# 5765    100000  Paid 399.99       Everyone                  Lifestyle
# 4606     50000  Paid 399.99       Everyone                    Finance
# 8825  10000000  Paid   0.99     Mature 17+                     Action
# 7151   1000000  Paid   6.99     Mature 17+                     Action
#
#       Revenue_Estimate
# 9220     69,900,000.00
# 5765     39,999,000.00
# 4606     19,999,500.00
# ...

# %% [markdown]
# # Plotly Bar Charts & Scatter Plots: Analysing App Categories

# %%
top10_categoies = df_apps_clean.Category.value_counts()[:10]

# %%
bar = px.bar(top10_categoies)
bar.show()

# %% [markdown]
# ### how often apps are downloaded in that category.

# %%
# need to find the sum of installs per category
category_installs = df_apps_clean.groupby('Category').agg({'Installs': pd.Series.sum})
category_installs.sort_values('Installs', ascending=True, inplace=True)

hbar = px.bar(category_installs, orientation="h")

hbar.show()
# Out:
# <div>                            <div id="c7361d3a-c7a8-4c5d-9e6e-a7f6c94b3137" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("c7361d3a-c7a8-4c5d-9e6e-a7f6c94b3137")) {                    Plotly.newPlot(                        "c7361d3a-c7a8-4c5d-9e6e-a7f6c94b3137",                        [{"alignmentgroup":"True","hovertemplate":"variable=Installs<br>value=%{x}<br>Category=%{y}<extra></extra>","legendgroup":"Installs","marker":{"color":"#636efa","pattern":{"shape":""}},"name":"Installs","offsetgroup":"Installs","orientation":"h","showlegend":true,"textposition":"auto","x":[15949410,26916200,31116110,39162676,44931100,52083000,53129800,97082000,114233100,140912410,211677750,352852000,361096500,455312400,503267560,503742120,692018120,1096431465,1134
# ...

# %% [markdown]
# ### Category Concentration - Downloads vs. Competition
#
# **Challenge**:
# * First, create a DataFrame that has the number of apps in one column and the number of installs in another:
#
# <img src=https://imgur.com/uQRSlXi.png width="350">
#
# * Then use the [plotly express examples from the documentation](https://plotly.com/python/line-and-scatter/) alongside the [.scatter() API reference](https://plotly.com/python-api-reference/generated/plotly.express.scatter.html)to create scatter plot that looks like this.
#
# <img src=https://imgur.com/cHsqh6a.png>
#
# *Hint*: Use the size, hover_name and color parameters in .scatter(). To scale the yaxis, call .update_layout() and specify that the yaxis should be on a log-scale like so: yaxis=dict(type='log')

# %%
data1 = df_apps_clean.groupby("Category").agg({"App": "count", 'Installs': "sum"}).sort_values("App", ascending=False)

data1
# Out:
#                       App     Installs
# Category
# FAMILY               1610   4437579590
# GAME                  910  13858762717
# TOOLS                 719   8099724500
# LIFESTYLE             302    503742120
# FINANCE               302    455312400
# PRODUCTIVITY          301   5788070180
# PERSONALIZATION       298   1532352930
# MEDICAL               292     39162676
# PHOTOGRAPHY           263   4649143130
# BUSINESS              262    692018120
# SPORTS                260   1096431465
# COMMUNICATION         257  11039241530
# HEALTH_AND_FITNESS    243   1134006220
# NEWS_AND_MAGAZINES    204   2369110650
# SOCIAL                203   5487841475
# TRAVEL_AND_LOCAL      187   2894859300
# SHOPPING              180   1400331540
# BOOKS_AND_REFERENCE   169   1665791655
# VIDEO_PLAYERS         148   3916897200
# DATING                134    140912410
# EDUCATION             118    352852000
# MAPS_AND_NAVIGATION   118    503267560
# ENTERTAINMENT         102   2113660000
# ...

# %% [markdown]
# # Grouped Bar Charts: Free vs. Paid Apps per Category

# %%
df_free_vs_paid = df_apps_clean.groupby(["Category", "Type"], as_index=False).agg({'App': "count"})
df_free_vs_paid
# Out:
#              Category  Type  App
# 0      ART_AND_DESIGN  Free   58
# 1      ART_AND_DESIGN  Paid    3
# 2   AUTO_AND_VEHICLES  Free   72
# 3   AUTO_AND_VEHICLES  Paid    1
# 4              BEAUTY  Free   42
# ..                ...   ...  ...
# 56   TRAVEL_AND_LOCAL  Paid    8
# 57      VIDEO_PLAYERS  Free  144
# 58      VIDEO_PLAYERS  Paid    4
# 59            WEATHER  Free   65
# 60            WEATHER  Paid    7
#
# [61 rows x 3 columns]

# %% [markdown]
# **Challenge**: Use the plotly express bar [chart examples](https://plotly.com/python/bar-charts/#bar-chart-with-sorted-or-ordered-categories) and the [.bar() API reference](https://plotly.com/python-api-reference/generated/plotly.express.bar.html#plotly.express.bar) to create this bar chart:
#
# <img src=https://imgur.com/LE0XCxA.png>
#
# You'll want to use the `df_free_vs_paid` DataFrame that you created above that has the total number of free and paid apps per category.
#
# See if you can figure out how to get the look above by changing the `categoryorder` to 'total descending' as outlined in the documentation here [here](https://plotly.com/python/categorical-axes/#automatically-sorting-categories-by-name-or-total-value).

# %%
fig2 = px.bar(data_frame=df_free_vs_paid,
              x="Category",
              y="App",
              color="Type",
              barmode="group")
fig2.update_layout(xaxis_title='Category',
                    yaxis_title='Number of Apps',
                    xaxis={'categoryorder':'total descending'},
                    yaxis=dict(type='log'))
fig2.show()
# Out:
# <div>                            <div id="58113083-61b0-4843-ad7e-96303f915111" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("58113083-61b0-4843-ad7e-96303f915111")) {                    Plotly.newPlot(                        "58113083-61b0-4843-ad7e-96303f915111",                        [{"alignmentgroup":"True","hovertemplate":"Type=Free<br>Category=%{x}<br>App=%{y}<extra></extra>","legendgroup":"Free","marker":{"color":"#636efa","pattern":{"shape":""}},"name":"Free","offsetgroup":"Free","orientation":"v","showlegend":true,"textposition":"auto","x":["ART_AND_DESIGN","AUTO_AND_VEHICLES","BEAUTY","BOOKS_AND_REFERENCE","BUSINESS","COMICS","COMMUNICATION","DATING","EDUCATION","ENTERTAINMENT","EVENTS","FAMILY","FINANCE","FOOD_AND_DRINK","GAME","HEALT
# ...

# %% [markdown]
# # Plotly Box Plots: Lost Downloads for Paid Apps
#
# **Challenge**: Create a box plot that shows the number of Installs for free versus paid apps. How does the median number of installations compare? Is the difference large or small?
#
# Use the [Box Plots Guide](https://plotly.com/python/box-plots/) and the [.box API reference](https://plotly.com/python-api-reference/generated/plotly.express.box.html) to create the following chart.
#
# <img src=https://imgur.com/uVsECT3.png>

# %%
fig3 = px.box(data_frame=df_apps_clean,
              x="Type",
              y="Installs",
              color="Type",
              notched=True,
              points='all',
              title='How Many Downloads are Paid Apps Giving Up?')

fig3.update_layout(yaxis=dict(type='log'))

fig3.show()
# Out:
# <div>                            <div id="c7cdb261-bdf9-4528-873b-1b3d0f728120" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("c7cdb261-bdf9-4528-873b-1b3d0f728120")) {                    Plotly.newPlot(                        "c7cdb261-bdf9-4528-873b-1b3d0f728120",                        [{"alignmentgroup":"True","boxpoints":"all","hovertemplate":"Type=%{x}<br>Installs=%{y}<extra></extra>","legendgroup":"Free","marker":{"color":"#636efa"},"name":"Free","notched":true,"offsetgroup":"Free","orientation":"v","showlegend":true,"x":["Free","Free","Free","Free","Free","Free","Free","Free","Free","Free","Free","Free","Free","Free","Free","Free","Free","Free","Free","Free","Free","Free","Free","Free","Free","Free","Free","Free","Free","Free","Free","Free"
# ...

# %% [markdown]
# # Plotly Box Plots: Revenue by App Category
#
# **Challenge**: See if you can generate the chart below:
#
# <img src=https://imgur.com/v4CiNqX.png>
#
# Looking at the hover text, how much does the median app earn in the Tools category? If developing an Android app costs $30,000 or thereabouts, does the average photography app recoup its development costs?
#
# Hint: I've used 'min ascending' to sort the categories.

# %%
fig4 = px.box(data_frame=df_apps_clean[df_apps_clean['Type'] == 'Paid'],
              x="Category",
              y="Revenue_Estimate",
              title='How Much Can Paid Apps Earn?')

fig4.update_layout(xaxis_title='Category',
                  yaxis_title='Paid App Ballpark Revenue',
                  xaxis={'categoryorder':'min ascending'},
                  yaxis=dict(type='log'))

fig4.show()
# Out:
# <div>                            <div id="c025dad7-41c3-4f25-9b60-ff2a2f840e62" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("c025dad7-41c3-4f25-9b60-ff2a2f840e62")) {                    Plotly.newPlot(                        "c025dad7-41c3-4f25-9b60-ff2a2f840e62",                        [{"alignmentgroup":"True","hovertemplate":"Category=%{x}<br>Revenue_Estimate=%{y}<extra></extra>","legendgroup":"","marker":{"color":"#636efa"},"name":"","notched":false,"offsetgroup":"","orientation":"v","showlegend":false,"x":["GAME","GAME","FAMILY","BUSINESS","LIFESTYLE","FAMILY","PERSONALIZATION","PHOTOGRAPHY","FAMILY","GAME","PRODUCTIVITY","PHOTOGRAPHY","FAMILY","TOOLS","TOOLS","PERSONALIZATION","FAMILY","FAMILY","FAMILY","FAMILY","GAME","TOOLS","PERSONALIZAT
# ...
